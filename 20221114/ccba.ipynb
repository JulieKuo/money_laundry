# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ccba = pd.read_csv("data/inverse/ccba.csv")
ccba["byymm"] = pd.to_datetime(ccba["byymm"])
print(ccba.shape)
print("cust_id:", ccba["cust_id"].nunique())
ccba.head()
# Out:
# (59075, 10)
# cust_id: 4745
#                                              cust_id    lupay      byymm  \
# 0  0015cc01f553512007705edf855baa16f1b57a16fb107e...   3920.0 2021-04-01
# 1  0015cc01f553512007705edf855baa16f1b57a16fb107e...  16576.0 2021-05-01
# 2  0015cc01f553512007705edf855baa16f1b57a16fb107e...   8653.0 2021-06-01
# 3  0015cc01f553512007705edf855baa16f1b57a16fb107e...   5045.0 2021-07-01
# 4  0015cc01f553512007705edf855baa16f1b57a16fb107e...   4334.0 2021-08-01
#
#       cycam    usgam  clamt  csamt   inamt    cucsm  cucah
# 0  134614.0  32316.0    0.0    0.0  3148.0  16576.0    0.0
# 1  134614.0  22280.0    0.0    0.0  3148.0   8653.0    0.0
# 2  134614.0  14771.0    0.0    0.0  3148.0   5045.0    0.0
# 3  134614.0  10954.0    0.0    0.0  3148.0   4334.0    0.0
# 4  134614.0   7544.0    0.0    0.0  3148.0   4396.0    0.0

# %%
ccba["amt_over"] = ccba.eval("usgam > cycam").astype(int)
ccba
# Out:
#                                                  cust_id    lupay      byymm  \
# 0      0015cc01f553512007705edf855baa16f1b57a16fb107e...   3920.0 2021-04-01
# 1      0015cc01f553512007705edf855baa16f1b57a16fb107e...  16576.0 2021-05-01
# 2      0015cc01f553512007705edf855baa16f1b57a16fb107e...   8653.0 2021-06-01
# 3      0015cc01f553512007705edf855baa16f1b57a16fb107e...   5045.0 2021-07-01
# 4      0015cc01f553512007705edf855baa16f1b57a16fb107e...   4334.0 2021-08-01
# ...                                                  ...      ...        ...
# 59070  ffeb846f2294ec4397f800736dc1e14eb754da5425398d...      0.0 2021-12-01
# 59071  ffeb846f2294ec4397f800736dc1e14eb754da5425398d...  61927.0 2022-01-01
# 59072  ffeb846f2294ec4397f800736dc1e14eb754da5425398d...  37297.0 2022-02-01
# 59073  ffeb846f2294ec4397f800736dc1e14eb754da5425398d...  19766.0 2022-03-01
# 59074  ffeb846f2294ec4397f800736dc1e14eb754da5425398d...   2591.0 2022-04-01
#
# ...

# %%
ccba.to_csv("data/feat_gen/ccba.csv", index = False)
